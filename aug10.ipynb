# %% [markdown]
# # Operators
# ## Relational / Comparison Operators
# ### > , < , >= , <=
# ## Equality operators
# ### == (equals to equals), != (not equals to)
# ## Rellational Operators always return boolean value(True / False)

# %%
Jay = 21
Viru = 22

print(Jay > Viru) #False
# Out:
# False

# %%
print(Jay != Viru) 
print(Jay == Viru)
# Out:
# True
# False

# %% [markdown]
# # Conditional Statements
#
# ## if :->
# ### to check hald condition
#
#
# ## if - else
# ### ---> we use if - else to check one complete condtiton
#
# ### sty:->      if condition:
# ###                 if Block Code
# ###             else :
# ###                 else block code

# %%
jay = 42
viru = 42

#Who will pay the bill

if jay > viru:
    print("jay will pay the bill")
elif jay == viru:
    print("both will pay the bill")
else:
    print("viru will pay the bill")

print("End of the program")
# Out:
# both will pay the bill
# End of the program

# %% [markdown]
# ### Note : if --> False then python executes else statement

# %% [markdown]
# # Logical operators
# ### and
# ### or
# ### not
#
# ## for logical operators on data we use logical operatos

# %% [markdown]
# ## and oprator :->
#     if all the operands are true then and then only op is TRUE otherwise False.

# %%
var1 = True
var2 = True

print("var1,2: ", var1 and var2) #True

var3 = False
var4 = True

print("var3,4: ", var3 and var4) #False

var5 = False
var6 = False

print("var5,6: ", var5 and var6) #False

print ("var1,2,3 : ", var1 and  var2 and var3)
# Out:
# var1,2:  True
# var3,4:  False
# var5,6:  False
# var1,2,3 :  False

# %%
jay = 42
viru = 33
gabbar = 43

if (jay > viru) and (jay > gabbar): 
    print("jay will pay the bill")
elif (viru > jay) and (viru > gabbar):
    print("viru will pay the bill")
else:
    print("gabbar will pay the bill")
# Out:
# gabbar will pay the bill

# %% [markdown]
# ## or :->
#     if any operand is True o/p Is True
#     if all the operands are false then and then only op is false

# %%
c1 = "samsung"
c2 = "apple"
c3 = "oneplus"

if (c1 == "samsung") or (c2 == "apple") :
    print("I will buy the phone")
# Out:
# I will buy the phone

# %% [markdown]
# ## NOT :-> INVERSION OPERTOR

# %%
VAR = True

print ( not VAR )
# Out:
# False
