# %% [markdown]
# # Python List Practice — Set 2 (Different Data & Questions)Same structure as before (Sections A–D), but with a different list, different questions, and new challenge problems.

# %% [markdown]
# ## Section A: Basic List Tasks

# %%
# ============================================================# SECTION A: Basic List Tasks# ============================================================nums = [8, 22, 15, 22, 9, 40, 3, 15, 18, 40]# 1. Print all elements from the list.print(nums)# 2. Print the element at index 4.print("Element at index 4:", nums[4])# 3. Print the number of elements in the list.print("Total elements:", len(nums))# 4. Find the average of all elements.print("Average:", sum(nums) / len(nums))# 5. Find the largest and smallest number.print("Maximum Number:", max(nums))print("Minimum Number:", min(nums))# 6. Print all numbers divisible by 3.divisible_by_3 = []for n in nums:    if n % 3 == 0:        print("Divisible by 3:", n)        divisible_by_3.append(n)# 7. Print all numbers not divisible by 3.not_divisible_by_3 = []for n in nums:    if n % 3 != 0:        print("Not divisible by 3:", n)        not_divisible_by_3.append(n)# 8. Count how many numbers are divisible and not divisible by 3.print("Divisible by 3 count:", len(divisible_by_3))print("Not divisible by 3 count:", len(not_divisible_by_3))# 9. Check whether 18 exists in the list.print("18 exists in the list:", 18 in nums)# 10. Find the index position of 40 (first occurrence).print("Index position of 40:", nums.index(40))# 11. Add 99 at the end of the list.nums.append(99)print("Updated list:", nums)# 12. Insert 60 at index position 2.nums.insert(2, 60)print("Updated list:", nums)# 13. Remove the first occurrence of 22.nums.remove(22)print("Updated list:", nums)# 14. Remove duplicate values from the list, keeping order.unique = list(dict.fromkeys(nums))print("Unique values (order kept):", unique)# 15. Sort the list in ascending and descending order.nums.sort()print("Ascending order:", nums)nums.sort(reverse=True)print("Descending Order:", nums)

# %% [markdown]
# ## Section B: Logical List Tasks

# %%
# ============================================================# SECTION B: Logical List Tasks# ============================================================nums = [8, 22, 15, 22, 9, 40, 3, 15, 18, 40]# 16. Create a new list containing the cube of every number.cubes = []for n in nums:    cubes.append(n ** 3)print("Cubes:", cubes)# 17. Create a new list containing only numbers less than 20.less_than_20 = []for n in nums:    if n < 20:        less_than_20.append(n)print("Numbers less than 20:", less_than_20)# 18. Find the third-largest number.unique_sorted = sorted(set(nums), reverse=True)print("Third largest number:", unique_sorted[2])# 19. Find the range of the list (max - min).print("Range:", max(nums) - min(nums))# 20. Find how many numbers are above the average.avg = sum(nums) / len(nums)above_avg = []for n in nums:    if n > avg:        above_avg.append(n)print("Numbers above average:", above_avg)print("Count above average:", len(above_avg))

# %% [markdown]
# ## Section C: String List Tasks

# %%
# ============================================================# SECTION C: String List Tasks# ============================================================cities = ["Pune", "Mumbai", "Delhi", "Bangalore", "Nagpur", "Indore"]# 21. Print all city names.print(cities)# 22. Print names ending with "e".ends_e = []for city in cities:    if city.endswith("e"):        ends_e.append(city)print("Cities ending with 'e':", ends_e)# 23. Print names with exactly 5 letters.five_letter = []for city in cities:    if len(city) == 5:        five_letter.append(city)print("5-letter city names:", five_letter)# 24. Convert every name to lowercase.lower_cities = []for city in cities:    lower_cities.append(city.lower())print("Lowercase names:", lower_cities)# 25. Find the shortest city name.shortest = cities[0]for city in cities:    if len(city) < len(shortest):        shortest = cityprint("Shortest city name:", shortest)

# %% [markdown]
# ## Section D: Challenging List Tasks

# %%
# ============================================================# SECTION D: Challenging List Tasks# ============================================================# 26. Find the maximum difference between any two elements.lst = [4, 9, 1, 32, 12]max_diff = max(lst) - min(lst)print("Maximum difference:", max_diff)# 27. Rotate a list one position to the left.lst = [1, 2, 3, 4, 5]rotated_left = lst[1:] + [lst[0]]print("List rotated left by one position:", rotated_left)# 28. Flatten a list of lists into a single list.nested = [[1, 2], [3, 4], [5, 6, 7]]flat = []for sub in nested:    for item in sub:        flat.append(item)print("Flattened list:", flat)# 29. Find the frequency of the most common element.lst = [1, 2, 2, 3, 2, 4, 1]counts = {}for n in lst:    counts[n] = counts.get(n, 0) + 1most_common = max(counts, key=counts.get)print("Most common element:", most_common, "-> appears", counts[most_common], "times")# 30. Check if two lists have any elements in common.list1 = [1, 2, 3]list2 = [4, 5, 6]has_common = Falsefor n in list1:    if n in list2:        has_common = Trueprint("Lists share at least one element:", has_common)
